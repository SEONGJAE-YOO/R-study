# %% [markdown]
# # 1. 교차분석

# %%
data <- read.csv("./data/cleanDescriptive.csv", header=TRUE)

# %%
data
# Out:
#     resident gender age level cost type survey pass cost2 resident2 gender2
# 1    1       1      50   1    5.1  1     1      2    2    특별시    남자
# 2    2       1      54   2    4.2  1     2      2    2    광역시    남자
# 3   NA       1      62   2    4.7  1     1      1    2    NA        남자
# 4    4       2      50  NA    3.5  1     4      1   NA    광역시    여자
# 5    5       1      51   1    5.0  1     3      1    2    시구군    남자
# 6    3       1      55   2    5.4  1     3     NA    2    광역시    남자
# 7    2       2      56   1    4.1  1    NA      2    2    광역시    여자
# 8   NA       1      49   1    4.4  1    NA      2    2    NA        남자
# 9    2       1      49   2    4.9  1     1      1    2    광역시    남자
# 10   5       2      49  NA    2.3  1     2      1    1    시구군    여자
# 11   3       1      52   1    4.2  1     2      2    2    광역시    남자
# 12   1       1      57   1    6.7  1     2      1   NA    특별시    남자
# 13   2       2      51   3    4.3  1     2      1    2    광역시    여자
# 14   1       1      63   1    5.7  1    NA      2    2    특별시    남자
# 15   3       1      55   2    4.6  2    NA      2    2    광역시    남자
# 16   2       1      54   1    5.1  1    NA      2    2    광역시    남자
# 17   1       2      48   2    2.1  1    NA      2    1    특별시    여자
# 18   1       1      57   1    5.1  2    NA      2    2    특별시    남자
# 19   1       1      49  NA    6.2  2    NA      2   NA    특별시    남자
# 20   1       1      65   1    5.1  1     2      1    2    특별시    남자
# 21   2       1      49   1    4.1  1     2      1    2    광역시    남자
# 22   1       1      53   2    4.1  1     1      1    2    특별시    남자
# 23   2       2      45   3    2.3  1     3      1    1    광역시    여자
# 24   1       1      55   1    5.0  1     3      1    2    특별시    남자
# 25   2       1      60   2    5.2  2     2      1    2    광역시    남자
# 26   1       2      48   1    4.7  2    NA      2    2    특별시    여자
# 27   2       1      65   2    4.4  2    NA      2    2    광역시    남자
# 28   1       1      55   1    5.2  2    NA      2    2    특별시    남자
# 29   2       2      48   1    6.3  1    NA      2   NA    광역시    여자
# 30   5       1      63   3    4.0  1    NA      2    2    시구군    남자
# ... ...      ...    ... ...   ...  ...  ...    ...  ...   ...       ...
# 219  2       2      47   1    5.4  2     1      1    2    광역시    여자
# 220  3       2      49   3    7.0  1    NA      2    3    광역시    여자
# 221  4       2      64   2    6.0  1     2      1    2    광역시    여자
# 222  1       1      65   3    6.2  1     3      1   NA    특별시    남자
# 223  3       2      46   3    6.1  1    NA     NA   NA    광역시    여자
# 224  1       2      47   1    5.0  1     3      1    2    특별시    여자
# 225  1       2      57   2    5.8  1     4      1    2    특별시    여자
# 226  5       1      48   3    4.0  1     3      2    2    시구군    남자
# 227  3       2      58   1    3.0  1     4      2    1    광역시    여자
# 228  1       2      65   1    5.0  1     3      1    2    특별시    여자
# 229  5       1      55   2    6.0  1     4      1    2    시구군    남자
# 230  1       2      61  NA    6.2  2    NA      2   NA    특별시    여자
# 231  5       1      49   3    6.4  2    NA      2   NA    시구군    남자
# 232  5       2      45   3    7.9  1     2      1    3    시구군    여자
# 233  1       1      59  NA    6.4  1    NA     NA   NA    특별시    남자
# 234  2       2      48   3    6.3  1    NA      2   NA    광역시    여자
# 235 NA       1      60   1    6.1  1    NA      2   NA    NA        남자
# 236  2       2      47   2    6.3  2    NA      2   NA    광역시    여자
# 237  4       2      49   1    6.0  2     1      1    2    광역시    여자
# 238  2       2      63   1    6.9  1     2      1   NA    광역시    여자
# 239  2       1      47   2    6.2  1    NA      2   NA    광역시    남자
# 240  1       2      57   1    5.9  1    NA      2    2    특별시    여자
# 241  1       2      58   2    6.9  1    NA      2   NA    특별시    여자
# 242  5       2      55   1    7.7  1     1      2    3    시구군    여자
# 243  1       2      58   3    6.3  1     2      2   NA    특별시    여자
# 244  1       2      62   2    4.5  1     3      1    2    특별시    여자
# 245  2       1      65   1    3.5  1    NA      2   NA    광역시    남자
# 246  3       1      55   3    6.1  1    NA      2   NA    광역시    남자
# 247  4       1      51   1    5.5  1    NA     NA    2    광역시    남자
# 248  1       1      49   3    4.4  1    NA      2    2    특별시    남자
#     age2   level2   pass2
# 1   장년층 고졸     실패
# 2   장년층 대졸     실패
# 3   노년층 대졸     합격
# 4   장년층 NA       합격
# 5   장년층 고졸     합격
# 6   장년층 대졸     NA
# 7   장년층 고졸     실패
# 8   장년층 고졸     실패
# 9   장년층 대졸     합격
# 10  장년층 NA       합격
# 11  장년층 고졸     실패
# 12  장년층 고졸     합격
# 13  장년층 대학원졸 합격
# 14  노년층 고졸     실패
# 15  장년층 대졸     실패
# 16  장년층 고졸     실패
# 17  장년층 대졸     실패
# 18  장년층 고졸     실패
# 19  장년층 NA       실패
# 20  노년층 고졸     합격
# 21  장년층 고졸     합격
# 22  장년층 대졸     합격
# 23  중년층 대학원졸 합격
# 24  장년층 고졸     합격
# 25  노년층 대졸     합격
# 26  장년층 고졸     실패
# 27  노년층 대졸     실패
# 28  장년층 고졸     실패
# 29  장년층 고졸     실패
# 30  노년층 대학원졸 실패
# ... ...    ...      ...
# 219 장년층 고졸     합격
# 220 장년층 대학원졸 실패
# 221 노년층 대졸     합격
# 222 노년층 대학원졸 합격
# 223 장년층 대학원졸 NA
# 224 장년층 고졸     합격
# 225 장년층 대졸     합격
# 226 장년층 대학원졸 실패
# 227 장년층 고졸     실패
# 228 노년층 고졸     합격
# 229 장년층 대졸     합격
# 230 노년층 NA       실패
# 231 장년층 대학원졸 실패
# 232 중년층 대학원졸 합격
# 233 장년층 NA       NA
# 234 장년층 대학원졸 실패
# 235 노년층 고졸     실패
# 236 장년층 대졸     실패
# 237 장년층 고졸     합격
# 238 노년층 고졸     합격
# 239 장년층 대졸     실패
# 240 장년층 고졸     실패
# 241 장년층 대졸     실패
# 242 장년층 고졸     실패
# 243 장년층 대학원졸 실패
# 244 노년층 대졸     합격
# 245 노년층 고졸     실패
# 246 장년층 대학원졸 실패
# 247 장년층 고졸     NA
# 248 장년층 대학원졸 실패

# %%
head(data)
# Out:
#   resident gender age level cost type survey pass cost2 resident2 gender2
# 1  1       1      50   1    5.1  1    1       2    2    특별시    남자
# 2  2       1      54   2    4.2  1    2       2    2    광역시    남자
# 3 NA       1      62   2    4.7  1    1       1    2    NA        남자
# 4  4       2      50  NA    3.5  1    4       1   NA    광역시    여자
# 5  5       1      51   1    5.0  1    3       1    2    시구군    남자
# 6  3       1      55   2    5.4  1    3      NA    2    광역시    남자
#   age2   level2 pass2
# 1 장년층 고졸   실패
# 2 장년층 대졸   실패
# 3 노년층 대졸   합격
# 4 장년층 NA     합격
# 5 장년층 고졸   합격
# 6 장년층 대졸   NA

# %%
dim(data)
# Out:
# [1] 248  14

# %%
# 변수 추출
x <- data$level2 
y <- data$pass2

# %%
# 데이터 프레임 생성 
df <- data.frame(Level=x,Pass=y)
table(df$Level) # row
table(df$Pass) # column
# Out:
#     고졸     대졸 대학원졸
#       93       86       57
# 실패 합격
#   96  139

# %%
# 1) 교차분할표 생성  
table(df) # 빈도보기
# Out:
#           Pass
# Level      실패 합격
#   고졸       40   49
#   대졸       27   55
#   대학원졸   23   31

# %%
# 2) package를 이용한 교차분할표 생성
install.packages("gmodels") # gmodels 패키지 설치
library(gmodels) # CrossTable() 함수 사용

CrossTable(x=df$Level, y=df$Pass)
# Out:
# also installing the dependencies 'gtools', 'gdata'
#   There is a binary version available but the source version is later:
#        binary source needs_compilation
# gtools  3.8.2  3.9.2              TRUE
#
#   Binaries will be installed
# package 'gtools' successfully unpacked and MD5 sums checked
# package 'gdata' successfully unpacked and MD5 sums checked
# package 'gmodels' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\MyCom\AppData\Local\Temp\RtmpgnDCWZ\downloaded_packages
# Warning message:
# "package 'gmodels' was built under R version 3.6.3"
#
#    Cell Contents
# |-------------------------|
# |                       N |
# | Chi-square contribution |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  225
#
#
#              | df$Pass
#     df$Level |      실패 |      합격 | Row Total |
# -------------|-----------|-----------|-----------|
#         고졸 |        40 |        49 |        89 |
#              |     0.544 |     0.363 |           |
#              |     0.449 |     0.551 |     0.396 |
#              |     0.444 |     0.363 |           |
#              |     0.178 |     0.218 |           |
# -------------|-----------|-----------|-----------|
#         대졸 |        27 |        55 |        82 |
#              |     1.026 |     0.684 |           |
#              |     0.329 |     0.671 |     0.364 |
#              |     0.300 |     0.407 |           |
#              |     0.120 |     0.244 |           |
# -------------|-----------|-----------|-----------|
#     대학원졸 |        23 |        31 |        54 |
#              |     0.091 |     0.060 |           |
#              |     0.426 |     0.574 |     0.240 |
#              |     0.256 |     0.230 |           |
#              |     0.102 |     0.138 |           |
# -------------|-----------|-----------|-----------|
# Column Total |        90 |       135 |       225 |
#              |     0.400 |     0.600 |           |
# -------------|-----------|-----------|-----------|

# %% [markdown]
# # p-value(유의 확률, significance probability)
#
#
# p-value는, 귀무가설(null hypothesis, H0)이 맞다는 전제 하에, 통계값(statistics)이 실제로 관측된 값 이상일 확률을 의미한다.
#
# 일반적으로 p-value는 어떤 가설을 전제로, 그 가설이 맞는다는 가정 하에, 내가 현재 구한 통계값이 얼마나 자주 나올 것인가, 를 의미한다고 할 수 있다. p-value는 가설검정이라는 것이 전체 데이터를 갖고 하는 것이 아닌 sampling 된 데이터를 갖고 하는 것이기 때문이다.
#
# 일반적으로 p-value < 0.05 혹은 0.01을 기준으로 합니다. 계산된 p-value가 기준값보다 작은 경우 귀무가설을 기각하는 것으로 즉, 극단적으로 귀무가설이 일어날 확률이 매우 낮은 상태를 의미합니다.
#
# - 참고사이트 [https://blog.minitab.com/ko/understanding-statistics/what-can-you-say-when-your-p-value-is-greater-than-005](https://blog.minitab.com/ko/understanding-statistics/what-can-you-say-when-your-p-value-is-greater-than-005)
#
# 대다수의 분석에서는 0.05의 알파가 유의성의 기준으로 사용됩니다. P값이 0.05 미만인 경우 평균 간에 차이가 없다는 귀무 가설을 기각하고 유의한 차이가 있다는 결론을 내리게 됩니다. P값이 0.05보다 크면 큰 차이가 존재한다는 결론을 내릴 수 없습니다.
#
# 0.05 미만이면 유의하고(의미가 있다) 0.05를 초과하면 유의하지 않습니다.
#
# (통계적 유의성은 모집단에 대한 가설이 가지는 통계적 의미를 말한다. 다시 말해서, 어떤 실험 결과 자료를 두고 "통계적으로 유의하다."라고 하는 것은 확률적으로 봐서 단순한 우연이라고 생각되지 않을 정도로 의미가 있다는 뜻이다. 반대로 "통계적으로 유의하지 않다."라고 하는 것은 실험 결과가 단순한 우연일 수도 있다는 뜻이다.)

# %% [markdown]
# - 귀무가설 이란?
#
# - 참고사이트 [https://drhongdatanote.tistory.com/59](https://drhongdatanote.tistory.com/59)
#
# 모집단의 특성에 대해 옳다고 제안하는 잠정적인 주장입니다. 귀무가설은 "모집단의 모수는 00와 같다." 또는 "모집단의 모수는 00와 차이가 없다."라고 가정하는 것을 말합니다.
#
# 예를 들어 만약 전국 20세 이상의 평균 키가 170cm라는 주장을 통계적으로 검정한다면, 이에 대한 귀무 가설은 "20세 이상의 성인 남자의 평균 키는 170cm과 같다.(또는 차이가 없다.)"가 될 것입니다.
# 또 제약회사에서 개발한 신약의 효과를 검정한다면, 귀무가설은 "개발한 신약은 효과가 없다.(또는 차이가 없다.)"가 됩니다.
#
# 즉 귀무가설은 효과는 없다 또는 "~와 같다" 라는 형식으로 설정된다는 것을 알 수 있습니다.

# %% [markdown]
# ## P값을 올바르게 해석하는 방법 How to Correctly Interpret P Values
#
# ### 참고사이트 - [https://blog.minitab.com/ko/adventures-in-statistics-2/how-to-correctly-interpret-p-values](https://blog.minitab.com/ko/adventures-in-statistics-2/how-to-correctly-interpret-p-values)
#
# P값이 높은 경우: 귀무 가설이 참일 가능성이 높은 데이터입니다.
#
# P값이 낮은 경우: 귀무 가설이 참일 가능성이 낮은 데이터입니다.

# %%
# <실습> 부모의 학력수준이 자녀의 대학진학에 영향이 있는가를   
#        알아보기 위해서 다음과 같이 교차분석을 수행하시오.
#<조건1> CrossTable()함수 이용
# 귀무가설 : 학년수준과 자녀의 대학진학여부와 관련이 없다.(O)
# 대립가설 : 학년수준과 자녀의 대학진학여부와 관련이 있다.(x)

# sample : 고졸(합격) : 49 
# 기대값 식 = (셀의 행합 * 셀의 열합) / 전체합
value = (90 * 135) / 225
value # 54
# 기대비율 식 = (관측값 - 기대값)^2/ 기대값 
rate = ((49 - p_value)^2) / p_value
rate # 0.462962962962963
# Out:
# [1] 54
# [1] 0.462963

# %%
# 교차분할표 & 카이검정 
CrossTable(x=df$Level, y=df$Pass, chisq = TRUE)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# | Chi-square contribution |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  225
#
#
#              | df$Pass
#     df$Level |      실패 |      합격 | Row Total |
# -------------|-----------|-----------|-----------|
#         고졸 |        40 |        49 |        89 |
#              |     0.544 |     0.363 |           |
#              |     0.449 |     0.551 |     0.396 |
#              |     0.444 |     0.363 |           |
#              |     0.178 |     0.218 |           |
# -------------|-----------|-----------|-----------|
#         대졸 |        27 |        55 |        82 |
#              |     1.026 |     0.684 |           |
#              |     0.329 |     0.671 |     0.364 |
#              |     0.300 |     0.407 |           |
#              |     0.120 |     0.244 |           |
# -------------|-----------|-----------|-----------|
#     대학원졸 |        23 |        31 |        54 |
#              |     0.091 |     0.060 |           |
#              |     0.426 |     0.574 |     0.240 |
#              |     0.256 |     0.230 |           |
#              |     0.102 |     0.138 |           |
# -------------|-----------|-----------|-----------|
# Column Total |        90 |       135 |       225 |
#              |     0.400 |     0.600 |           |
# -------------|-----------|-----------|-----------|
#
#
# Statistics for All Table Factors
#
#
# Pearson's Chi-squared test
# ------------------------------------------------------------
# Chi^2 =  2.766951     d.f. =  2     p =  0.2507057

# %% [markdown]
# # 결론 P값이 0.05 보다 크므로 실험 결과가 단순한 우연일 수도 있다는 뜻이고 귀무 가설이 참일 가능성이 높은 데이터입니다.
